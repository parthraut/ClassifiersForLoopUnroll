# %%
import pandas as pd

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv("datasets/dataset.csv")
columns = list(df.columns)
Y_columns = ["program_name", "optimal_luf", "loop_line_number"]
input_features = [x for x in columns if x not in Y_columns]
X = df[input_features]
Y = df["optimal_luf"]

features = set(X.columns)

# %% [markdown]
# # Filter

# %%
frequency = Y.value_counts()
print(frequency)
# Out:
# optimal_luf
# 1    71
# 4    33
# 8    32
# 3    27
# 5    27
# 6    25
# 2    22
# 7    10
# Name: count, dtype: int64

# %%
Y = Y[Y.isin([1, 4, 8])]
Y_indices = list(Y.index)
X = X.loc[Y_indices]

frequency = Y.value_counts()
print(frequency)
# Out:
# optimal_luf
# 1    71
# 4    33
# 8    32
# Name: count, dtype: int64

# %%
print(len(X))
# Out:
# 136

# %% [markdown]
# # Train RF

# %%
from sklearn.datasets import fetch_covtype
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV as grid_search
import numpy as np
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV, StratifiedKFold, cross_val_predict

# %% [markdown]
# ## Feature Selection

# %%
stop = False
best_score = 0
best_gsv = None
scores = list()
best_features = set()

curr_features = set()

while len(curr_features) < 5:
    print("\n====================")
    
    col_to_add = None
    best_curr_score = 0
    best_cur_gsv = None

    for column_name in (features - curr_features):
        print(f"Testing {column_name}")
        X_filtered = X[list(curr_features.union({column_name}))]

        clf = RandomForestClassifier(class_weight='balanced')
        params = {
            'n_estimators':[50, 100, 200],
            'max_features':[2, 5],
            'max_depth': [None, 10],
            'min_samples_split': [2, 5],
            'min_samples_leaf': [1, 2]
        }
        gsv = grid_search(clf, params, cv=5, n_jobs=-1, scoring='accuracy')
        gsv.fit(X_filtered, Y)

        if gsv.best_score_ > best_curr_score:
            best_curr_score = gsv.best_score_
            col_to_add = column_name
            best_cur_gsv = gsv
        
        print(f"Score: {gsv.best_score_}")

    if best_curr_score > best_score:
        best_score = best_curr_score
        best_gsv = best_cur_gsv
        curr_features.add(col_to_add)
        scores.append(best_curr_score)
        best_features = curr_features
        print(f"Found best!")
        print(f"Curr features: {curr_features}")
        print(f"Best score: {best_score}")

    elif abs(best_curr_score - best_score) >= 0.05:
        stop = True

    else:
        curr_features.add(col_to_add)
        scores.append(best_curr_score)
        print(f"Curr features: {curr_features}")
        print(f"Curr score: {best_curr_score}")
        print(f"Best score: {best_score}")
# Out:
# ====================
# Testing array_accesses
# Score: 0.3013227513227513
# Testing intra_loop_dependencies_flow
# Score: 0.43280423280423275
# Testing inter_loop_dependencies
# Score: 0.2936507936507936
# Testing aluf
# Score: 0.3592592592592593
# Testing loop_nest_level
# Score: 0.3455026455026455
# Testing intra_loop_dependencies_anti
# Score: 0.27936507936507937
# Testing max_inter_loop_dependency_distance
# Score: 0.44841269841269843
# Testing max_inter_loop_dependency_distance_flow
# Score: 0.521957671957672
# Testing max_intra_loop_dependency_distance_flow
# Score: 0.521957671957672
# Testing other
# Score: 0.3671957671957672
# Testing max_intra_loop_dependency_distance_output
# Score: 0.521957671957672
# Testing inter_loop_dependencies_flow
# Score: 0.521957671957672
# Testing inter_loop_dependencies_output
# Score: 0.36772486772486773
# Testing has_inter_loop_carried_dependency
# Score: 0.521957671957672
# Testing max_intra_loop_dependency_distance_anti
# Score: 0.521957671957672
# Testing array_reads
# Score: 0.31507936507936507
# Testing intra_loop_dependencies
# Score: 0.3597883597883597
# Testing load
# Score: 0.28624338624338624
# Testing max_intra_loop_dependency_distance
# Score: 0.521957671957672
# Testing instruction_sum
# Score: 0.31587301587301586
# Testing store
# Score: 0.45661375661375664
# Testing inter_loop_dependencies_anti
# Score: 0.4701058201058201
# Testing intra_loop_dependencies_output
# Score: 0.37592592592592594
# Testing branch
# Score: 0.34523809523809523
# Testing alui
# Score: 0.4185185185185185
# Testing trip_count
# Score: 0.358994708994709
# Testing mem
# Score: 0.38994708994708993
# Testing array_writes
# Score: 0.37407407407407406
# Testing operand_sum
# Score: 0.36005291005291007
# Testing resmii_111
# Score: 0.4992063492063492
# Testing max_inter_loop_dependency_distance_output
# Score: 0.4701058201058201
# Testing resmii_121
# Score: 0.45634920634920634
# Testing max_inter_loop_dependency_distance_anti
# Score: 0.4701058201058201
# Testing resmii_211
# Score: 0.4113756613756614
# Found best!
# Curr features: {'max_inter_loop_dependency_distance_flow'}
# Best score: 0.521957671957672
#
# ====================
# Testing array_accesses
# Score: 0.3232804232804233
# Testing intra_loop_dependencies_flow
# Score: 0.4701058201058201
# Testing inter_loop_dependencies
# Score: 0.28624338624338624
# Testing aluf
# Score: 0.33148148148148143
# Testing loop_nest_level
# Score: 0.3455026455026455
# Testing intra_loop_dependencies_anti
# Score: 0.30767195767195765
# Testing max_inter_loop_dependency_distance
# Score: 0.44841269841269843
# Testing max_intra_loop_dependency_distance_flow
# Score: 0.4701058201058201
# Testing other
# Score: 0.3671957671957672
# Testing max_intra_loop_dependency_distance_output
# Score: 0.4626984126984127
# Testing inter_loop_dependencies_flow
# Score: 0.4701058201058201
# Testing inter_loop_dependencies_output
# Score: 0.43439153439153444
# Testing has_inter_loop_carried_dependency
# Score: 0.4626984126984127
# Testing max_intra_loop_dependency_distance_anti
# Score: 0.4626984126984127
# Testing array_reads
# Score: 0.32275132275132273
# Testing intra_loop_dependencies
# Score: 0.34497354497354493
# Testing load
# Score: 0.2568783068783069
# Testing max_intra_loop_dependency_distance
# Score: 0.46296296296296297
# Testing instruction_sum
# Score: 0.3010582010582011
# Testing store
# Score: 0.45661375661375664
# Testing inter_loop_dependencies_anti
# Score: 0.5148148148148148
# Testing intra_loop_dependencies_output
# Score: 0.36693121693121694
# Testing branch
# Score: 0.3526455026455026
# Testing alui
# Score: 0.4185185185185185
# Testing trip_count
# Score: 0.3664021164021164
# Testing mem
# Score: 0.403968253968254
# Testing array_writes
# Score: 0.4404761904761905
# Testing operand_sum
# Score: 0.35238095238095235
# Testing resmii_111
# Score: 0.4992063492063492
# Testing max_inter_loop_dependency_distance_output
# Score: 0.46296296296296297
# Testing resmii_121
# Score: 0.47116402116402123
# Testing max_inter_loop_dependency_distance_anti
# Score: 0.4626984126984127
# Testing resmii_211
# Score: 0.4121693121693121
# Curr features: {'inter_loop_dependencies_anti', 'max_inter_loop_dependency_distance_flow'}
# Curr score: 0.5148148148148148
# Best score: 0.521957671957672
#
# ====================
# Testing array_accesses
# Score: 0.31587301587301586
# Testing intra_loop_dependencies_flow
# Score: 0.484920634920635
# Testing inter_loop_dependencies
# Score: 0.30767195767195765
# Testing aluf
# Score: 0.39629629629629626
# Testing loop_nest_level
# Score: 0.3455026455026455
# Testing intra_loop_dependencies_anti
# Score: 0.30767195767195765
# Testing max_inter_loop_dependency_distance
# Score: 0.45582010582010585
# Testing max_intra_loop_dependency_distance_flow
# Score: 0.4648148148148148
# Testing other
# Score: 0.36693121693121694
# Testing max_intra_loop_dependency_distance_output
# Score: 0.4648148148148148
# Testing inter_loop_dependencies_flow
# Score: 0.521957671957672
# Testing inter_loop_dependencies_output
# Score: 0.4121693121693122
# Testing has_inter_loop_carried_dependency
# Score: 0.4701058201058201
# Testing max_intra_loop_dependency_distance_anti
# Score: 0.521957671957672
# Testing array_reads
# Score: 0.32989417989417985
# Testing intra_loop_dependencies
# Score: 0.34523809523809523
# Testing load
# Score: 0.24947089947089945
# Testing max_intra_loop_dependency_distance
# Score: 0.5148148148148148
# Testing instruction_sum
# Score: 0.30846560846560844
# Testing store
# Score: 0.45661375661375664
# Testing intra_loop_dependencies_output
# Score: 0.32407407407407407
# Testing branch
# Score: 0.34523809523809523
# Testing alui
# Score: 0.4113756613756614
# Testing trip_count
# Score: 0.4034391534391534
# Testing mem
# Score: 0.4113756613756614
# Testing array_writes
# Score: 0.38835978835978835
# Testing operand_sum
# Score: 0.3526455026455026
# Testing resmii_111
# Score: 0.4917989417989418
# Testing max_inter_loop_dependency_distance_output
# Score: 0.4701058201058201
# Testing resmii_121
# Score: 0.4341269841269841
# Testing max_inter_loop_dependency_distance_anti
# Score: 0.4701058201058201
# Testing resmii_211
# Score: 0.41904761904761906
# Curr features: {'inter_loop_dependencies_anti', 'inter_loop_dependencies_flow', 'max_inter_loop_dependency_distance_flow'}
# Curr score: 0.521957671957672
# Best score: 0.521957671957672
#
# ====================
# Testing array_accesses
# Score: 0.3158730158730158
# Testing intra_loop_dependencies_flow
# Score: 0.4552910052910052
# Testing inter_loop_dependencies
# Score: 0.301058201058201
# Testing aluf
# Score: 0.3373015873015873
# Testing loop_nest_level
# Score: 0.3455026455026455
# Testing intra_loop_dependencies_anti
# Score: 0.33730158730158727
# Testing max_inter_loop_dependency_distance
# Score: 0.44841269841269843
# Testing max_intra_loop_dependency_distance_flow
# Score: 0.521957671957672
# Testing other
# Score: 0.35978835978835977
# Testing max_intra_loop_dependency_distance_output
# Score: 0.4701058201058201
# Testing inter_loop_dependencies_output
# Score: 0.43439153439153444
# Testing has_inter_loop_carried_dependency
# Score: 0.4701058201058201
# Testing max_intra_loop_dependency_distance_anti
# Score: 0.4626984126984127
# Testing array_reads
# Score: 0.32989417989417985
# Testing intra_loop_dependencies
# Score: 0.35978835978835977
# Testing load
# Score: 0.26428571428571423
# Testing max_intra_loop_dependency_distance
# Score: 0.4626984126984127
# Testing instruction_sum
# Score: 0.3082010582010582
# Testing store
# Score: 0.45661375661375664
# Testing intra_loop_dependencies_output
# Score: 0.32407407407407407
# Testing branch
# Score: 0.34523809523809523
# Testing alui
# Score: 0.42592592592592593
# Testing trip_count
# Score: 0.4185185185185185
# Testing mem
# Score: 0.403968253968254
# Testing array_writes
# Score: 0.38835978835978835
# Testing operand_sum
# Score: 0.37460317460317455
# Testing resmii_111
# Score: 0.4997354497354497
# Testing max_inter_loop_dependency_distance_output
# Score: 0.4701058201058201
# Testing resmii_121
# Score: 0.45634920634920634
# Testing max_inter_loop_dependency_distance_anti
# Score: 0.4701058201058201
# Testing resmii_211
# Score: 0.41878306878306876
# Curr features: {'inter_loop_dependencies_anti', 'inter_loop_dependencies_flow', 'max_inter_loop_dependency_distance_flow', 'max_intra_loop_dependency_distance_flow'}
# Curr score: 0.521957671957672
# Best score: 0.521957671957672
#
# ====================
# Testing array_accesses
# Score: 0.30899470899470893
# Testing intra_loop_dependencies_flow
# Score: 0.4703703703703703
# Testing inter_loop_dependencies
# Score: 0.28624338624338624
# Testing aluf
# Score: 0.3447089947089947
# Testing loop_nest_level
# Score: 0.3455026455026455
# Testing intra_loop_dependencies_anti
# Score: 0.31481481481481477
# Testing max_inter_loop_dependency_distance
# Score: 0.44841269841269843
# Testing other
# Score: 0.3671957671957672
# Testing max_intra_loop_dependency_distance_output
# Score: 0.4701058201058201
# Testing inter_loop_dependencies_output
# Score: 0.44153439153439156
# Testing has_inter_loop_carried_dependency
# Score: 0.521957671957672
# Testing max_intra_loop_dependency_distance_anti
# Score: 0.5148148148148148
# Testing array_reads
# Score: 0.32989417989417985
# Testing intra_loop_dependencies
# Score: 0.3521164021164021
# Testing load
# Score: 0.26375661375661374
# Testing max_intra_loop_dependency_distance
# Score: 0.4626984126984127
# Testing instruction_sum
# Score: 0.30846560846560844
# Testing store
# Score: 0.45661375661375664
# Testing intra_loop_dependencies_output
# Score: 0.3740740740740741
# Testing branch
# Score: 0.3526455026455026
# Testing alui
# Score: 0.42592592592592593
# Testing trip_count
# Score: 0.41084656084656085
# Testing mem
# Score: 0.4111111111111111
# Testing array_writes
# Score: 0.37407407407407406
# Testing operand_sum
# Score: 0.3526455026455026
# Testing resmii_111
# Score: 0.484920634920635
# Testing max_inter_loop_dependency_distance_output
# Score: 0.4626984126984127
# Testing resmii_121
# Score: 0.45634920634920634
# Testing max_inter_loop_dependency_distance_anti
# Score: 0.4701058201058201
# Testing resmii_211
# Score: 0.41878306878306876
# Curr features: {'max_inter_loop_dependency_distance_flow', 'max_intra_loop_dependency_distance_flow', 'inter_loop_dependencies_anti', 'inter_loop_dependencies_flow', 'has_inter_loop_carried_dependency'}
# Curr score: 0.521957671957672
# Best score: 0.521957671957672

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt


cv_predictions = cross_val_predict(best_gsv.best_estimator_, X_filtered, Y, cv=5, n_jobs=-1)

# Create confusion matrix
cm = confusion_matrix(Y, cv_predictions)

# Convert to percentages
cm_percentage = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

# Plot the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm_percentage, annot=True, fmt=".2f", cmap="Blues", xticklabels=np.unique(Y), yticklabels=np.unique(Y))
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix (Percentages)')
plt.show()

# %%
print(gsv.best_params_)
print(best_features)
# Out:
# {'max_depth': None, 'max_features': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# {'max_inter_loop_dependency_distance_flow', 'max_intra_loop_dependency_distance_flow', 'inter_loop_dependencies_anti', 'inter_loop_dependencies_flow', 'has_inter_loop_carried_dependency'}

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
print(f"Acc1: {best_score}")
precision = precision_score(Y, cv_predictions, average='weighted')
recall = recall_score(Y, cv_predictions, average='weighted')
f1 = f1_score(Y, cv_predictions, average='weighted')
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1: {f1}")
# Out:
# Acc1: 0.521957671957672
# Precision: 0.4448044247024323
# Recall: 0.41911764705882354
# F1: 0.42482836271763597

# %%
avg_err = 0
Y_list = list(Y)

for i in range(len(cv_predictions)):
    pred = cv_predictions[i]
    true = Y_list[i]
    avg_err += abs(pred-true)

avg_err /= len(cv_predictions)

print(f"Average error = {avg_err}")
